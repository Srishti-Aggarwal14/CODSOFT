# %% [markdown]
# <a href="https://colab.research.google.com/github/Srishti-Aggarwal14/CODSOFT/blob/main/Task_1_ToDoList.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
tasks=[]
def show_menu():
  print("\n---To-Do List Menu---")
  print("1.View Tasks")
  print("2.Add Tasks")
  print("3.Marks Task as Done")
  print("4. Delete Task")
  print("5.Exit")
def view_tasks():
  if not tasks:
    print("No tasks found")
  else:
    for i,task in enumerate(tasks,start=1):
      status="Done" if task['done'] else "Not Done"
      print(f"{i}.{task['title']} [{status}]")
def add_tasks():
    title=input("Enter task title:")
    tasks.append({'title':title,'done':False})
    print("Task added successfully")
def mark_task_done():
    view_tasks()
    task_index=int(input("Enter the task number to mark as done:"))-1
    if 0<=task_index<len(tasks):
      tasks[task_index]['done']=True
      print("Task marked as done")
    else:
      print("Invalid task number")
def delete_task():
    view_tasks()
    task_index=int(input("Enter the task number to delete:"))-1
    if 0<=task_index<len(tasks):
      del tasks[task_index]
      print("Task deleted successfully")
    else:
      print("Invalid task number")
while True:
  show_menu()
  choice=input("Enter your choice(1-5):")
  if choice=='1':
    view_tasks()
  elif choice=='2':
    add_tasks()
  elif choice=='3':
    mark_task_done()
  elif choice=='4':
    delete_task()
  elif choice=='5':
    print("Exiting the application")
    break
# Out:
# ---To-Do List Menu---
# 1.View Tasks
# 2.Add Tasks
# 3.Marks Task as Done
# 4. Delete Task
# 5.Exit
# Enter your choice(1-5):1
# No tasks found
#
# ---To-Do List Menu---
# 1.View Tasks
# 2.Add Tasks
# 3.Marks Task as Done
# 4. Delete Task
# 5.Exit
# Enter your choice(1-5):2
# Enter task title:Submit CODSOFT task 1
# Task added successfully
#
# ---To-Do List Menu---
# 1.View Tasks
# 2.Add Tasks
# 3.Marks Task as Done
# 4. Delete Task
# 5.Exit
# Enter your choice(1-5):2
# Enter task title:Practice Python
# Task added successfully
#
# ---To-Do List Menu---
# 1.View Tasks
# 2.Add Tasks
# 3.Marks Task as Done
# 4. Delete Task
# 5.Exit
# Enter your choice(1-5):1
# 1.Submit CODSOFT task 1 [Not Done]
# 2.Practice Python [Not Done]
#
# ---To-Do List Menu---
# 1.View Tasks
# 2.Add Tasks
# 3.Marks Task as Done
# 4. Delete Task
# 5.Exit
# Enter your choice(1-5):3
# 1.Submit CODSOFT task 1 [Not Done]
# 2.Practice Python [Not Done]
# Enter the task number to mark as done:1
# Task marked as done
#
# ...
